# %% [markdown]
# ## Vereadores mais votados do município do Rio de Janeiro por zona
#
# Esse programa lê o banco de dados oferecido pelo TSE para votações estaduais e seleciona os vereadores de um determinado município, filtrando apenas as variáveis desejadas, e gera um novo arquivo *.csv*.
#
# Esses dados podem ser encontrados no repositório de dados eleitorais do TSE:
# **http://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1/repositorio-de-dados-eleitorais**
#
# A lista de zonas eleitorais do Estado do Rio por bairro pode ser encontrada no site do TRE:
# http://www.tre-rj.jus.br/site/eleicoes/2016/arquivos/porBairroZon.xls

# %%
# Importa os dados dos candidatos do estado do Rio em 2016.
# Inicialmente são 30 as variáveis no banco de dados para cada linha.

import csv
import pandas as pd
import os

# Define como delimitador o ponto e vírgula
# Sem isso o Python lê a linha inteira do CSV com um índice único numa lista
csv.register_dialect('pVirgula', delimiter=';')
csv.register_dialect('virgula', delimiter=',')

# Importa os dados dos candidatos do estado do Rio em 2016
with open ('data/votacao_candidato_munzona_2016_RJ.csv', 'r', encoding="latin-1") as vot_f:
    leitor = csv.reader(vot_f, dialect='pVirgula')
    dados = list(leitor)
# Out:
# Tamanho inicial dos dados: 214803
# Exemplo de linha inicial:
# ['28/05/2019', '15:31:39', '2016', '2', 'Eleição Ordinária', '1', '220', 'ELEIÇÕES MUNICIPAIS 2016', '02/10/2016', 'M', 'RJ', '58017', 'ANGRA DOS REIS', '58017', 'ANGRA DOS REIS', '147', '11', 'Prefeito', '190000007860', '15', 'FERNANDO ANTÔNIO CECILIANO JORDÃO', 'FERNANDO JORDÃO', '#NULO#', '12', 'APTO', '2', 'DEFERIDO', 'Coligação', '15', 'PMDB', 'Partido do Movimento Democrático Brasileiro', '190000000335', 'ANGRA VAI VOLTAR A SORRIR', 'PMDB / PP / SD / PMN / PTN / PROS / PTB / PSB / PSC / PEN / PHS / PPL / PSL / PMB', '1', 'ELEITO', 'N', '40066']

# %%
# lista com os rótulos dos dados
cols = ['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO', 
           'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO', 
           'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE',
           'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_ZONA', 'CD_CARGO', 'DS_CARGO',
           'SQ_CANDIDATO', 'NR_CANDIDATO', 'NM_CANDIDATO', 'NM_URNA_CANDIDATO',
           'NM_SOCIAL_CANDIDATO', 'CD_SITUACAO_CANDIDATURA', 
           'DS_SITUACAO_CANDIDATURA', 'CD_DETALHE_SITUACAO_CAND', 
           'DS_DETALHE_SITUACAO_CAND', 'TP_AGREMIACAO', 'NR_PARTIDO', 
           'SG_PARTIDO', 'NM_PARTIDO', 'SQ_COLIGACAO', 'NM_COLIGACAO', 
           'DS_COMPOSICAO_COLIGACAO', 'CD_SIT_TOT_TURNO', 'DS_SIT_TOT_TURNO', 
           'ST_VOTO_EM_TRANSITO', 'QT_VOTOS_NOMINAIS']

drop_cols = ['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
         'NM_TIPO_ELEICAO', 'NR_TURNO', 'CD_ELEICAO', 'DS_ELEICAO',
         'DT_ELEICAO', 'TP_ABRANGENCIA', 'SG_UF', 'SG_UE', 'NM_UE',
         'CD_MUNICIPIO','CD_CARGO', 'SQ_CANDIDATO', 'NR_CANDIDATO',
         'NM_CANDIDATO', 'NM_SOCIAL_CANDIDATO', 'CD_SITUACAO_CANDIDATURA',
         'DS_SITUACAO_CANDIDATURA', 'CD_DETALHE_SITUACAO_CAND',
         'DS_DETALHE_SITUACAO_CAND', 'TP_AGREMIACAO', 'NM_PARTIDO',
         'SQ_COLIGACAO', 'NM_COLIGACAO', 'DS_COMPOSICAO_COLIGACAO',
         'CD_SIT_TOT_TURNO',  'ST_VOTO_EM_TRANSITO']

# Lista vazia para receber os candidatos
rows = []

# Loop para selecionar apenas os candidatos a vereador do município do rio
# que foram eleitos
for linhas in dados:
    if linhas[14] == "RIO DE JANEIRO" and linhas[17] == "Vereador" and linhas[35] != "SUPLENTE" and linhas[35] != "NÃO ELEITO":
        rows.append(linhas)
    else:
        continue

# Utilizando o Pandas, adiciona os rótulos das colunas e exclui as
# colunas indesejadas
ver = pd.DataFrame(rows)
ver.columns = cols
ver.drop(drop_cols, axis=1, inplace=True)

ver
# Out:
#         NM_MUNICIPIO NR_ZONA  DS_CARGO NM_URNA_CANDIDATO NR_PARTIDO  \
# 0     RIO DE JANEIRO     214  Vereador    TARCÍSIO MOTTA         50
# 1     RIO DE JANEIRO     162  Vereador    TARCÍSIO MOTTA         50
# 2     RIO DE JANEIRO     234  Vereador    PAULO PINHEIRO         50
# 3     RIO DE JANEIRO     170  Vereador   MARIELLE FRANCO         50
# 4     RIO DE JANEIRO     245  Vereador   MARIELLE FRANCO         50
# ...              ...     ...       ...               ...        ...
# 4942  RIO DE JANEIRO     228  Vereador     ROGERIO ROCAL         14
# 4943  RIO DE JANEIRO     124  Vereador     ROGERIO ROCAL         14
# 4944  RIO DE JANEIRO     252  Vereador     ROGERIO ROCAL         14
# 4945  RIO DE JANEIRO     245  Vereador     ROGERIO ROCAL         14
# 4946  RIO DE JANEIRO      23  Vereador     ROGERIO ROCAL         14
#
#      SG_PARTIDO  DS_SIT_TOT_TURNO QT_VOTOS_NOMINAIS
# 0          PSOL     ELEITO POR QP              1594
# 1          PSOL     ELEITO POR QP               322
# 2          PSOL     ELEITO POR QP                31
# 3          PSOL     ELEITO POR QP              1090
# 4          PSOL     ELEITO POR QP               181
# ...         ...               ...               ...
# 4942        PTB  ELEITO POR MÉDIA                 9
# 4943        PTB  ELEITO POR MÉDIA                39
# 4944        PTB  ELEITO POR MÉDIA                 2
# 4945        PTB  ELEITO POR MÉDIA               493
# 4946        PTB  ELEITO POR MÉDIA                13
#
# [4947 rows x 8 columns]

# %%
# Experimentações de análises com Pandas
zonas = ver.groupby(['NR_ZONA']).count()
zona = ver.loc[ver['NR_ZONA'] == '1']

zona.sort_values(['QT_VOTOS_NOMINAIS'], ascending=True)
# Out:
#         NM_MUNICIPIO NR_ZONA  DS_CARGO           NM_URNA_CANDIDATO NR_PARTIDO  \
# 353   RIO DE JANEIRO       1  Vereador                  ITALO CIBA         70
# 4871  RIO DE JANEIRO       1  Vereador              WILLIAN COELHO         15
# 3631  RIO DE JANEIRO       1  Vereador                        ZICO         14
# 3205  RIO DE JANEIRO       1  Vereador                RENATO MOURA         12
# 4425  RIO DE JANEIRO       1  Vereador              LUCIANA NOVAES         13
# 2798  RIO DE JANEIRO       1  Vereador                RENATO CINCO         50
# 2412  RIO DE JANEIRO       1  Vereador           OTONI DE PAULA JR         20
# 860   RIO DE JANEIRO       1  Vereador              ROSA FERNANDES         15
# 3211  RIO DE JANEIRO       1  Vereador     LUIZ CARLOS RAMOS FILHO         19
# 3542  RIO DE JANEIRO       1  Vereador         ALEXANDRE ISQUIERDO         25
# 4490  RIO DE JANEIRO       1  Vereador                   VERA LINS         11
#
#      SG_PARTIDO  DS_SIT_TOT_TURNO QT_VOTOS_NOMINAIS
# 353     PT do B     ELEITO POR QP                 1
# 4871       PMDB     ELEITO POR QP                11
# 3631        PTB     ELEITO POR QP                11
# 3205        PDT     ELEITO POR QP                11
# 4425         PT     ELEITO POR QP               117
# 2318        PEN     ELEITO POR QP                14
# 4060        PHS     ELEITO POR QP                15
# 842          PP     ELEITO POR QP                18
# 117        PMDB     ELEITO POR QP                19
# 881        PMDB     ELEITO POR QP                19
# 3146       PSOL     ELEITO POR QP               201
# 4100       PMDB     ELEITO POR QP                21
# 687          PT     ELEITO POR QP               227
# 2649        PDT  ELEITO POR MÉDIA               254
# 2899        PSC     ELEITO POR QP                27
# 1705         SD     ELEITO POR QP               288
# 4737        DEM  ELEITO POR MÉDIA                 3
# 3217        DEM     ELEITO POR QP               300
# 67          PSC     ELEITO POR QP               334
# 4327        PRB     ELEITO POR QP               348
# 1867        PHS  ELEITO POR MÉDIA                 4
# 1498       PSDB     ELEITO POR QP                40
# 4690        PRB     ELEITO POR QP                40
# 3336       PSOL     ELEITO POR QP                40
# 47         NOVO     ELEITO POR QP                40
# 2163       PSOL     ELEITO POR QP               401
# 2065       PSOL  ELEITO POR MÉDIA                44
# 2111       PMDB  ELEITO POR MÉDIA               444
# 4751       PMDB  ELEITO POR MÉDIA                53
# 3089         SD  ELEITO POR MÉDIA                57
# 577         PSD  ELEITO POR MÉDIA                57
# 2578        PRB     ELEITO POR QP                58
# 4313       PMDB     ELEITO POR QP                58
# 1302        PMN  ELEITO POR MÉDIA                 6
# 2777        PTB  ELEITO POR MÉDIA                 6
# 50          PSD     ELEITO POR QP                63
# 1211        PTB     ELEITO POR QP                66
# 38         PSDB     ELEITO POR QP                66
# 337        PMDB     ELEITO POR QP                67
# 3465       PROS  ELEITO POR MÉDIA                68
# 3677        PMN     ELEITO POR QP                 7
# 990        PSDB  ELEITO POR MÉDIA                 7
# 4115       PMDB     ELEITO POR QP                73
# 3221        DEM     ELEITO POR QP                74
# 552        PSOL  ELEITO POR MÉDIA                79
# 2798       PSOL     ELEITO POR QP                79
# 2412        PSC     ELEITO POR QP                 8
# 860        PMDB     ELEITO POR QP                81
# 3211        PTN     ELEITO POR QP                81
# 3542        DEM     ELEITO POR QP                85
# 4490         PP     ELEITO POR QP                87

# %%
#Salva os vereadores selecionados em um novo arquivo .csv
with open('data/votacao_filtro_munzona_2016_RJ.csv', 'w', encoding='latin-1', newline='') as novo_arquivo:
    escreve = csv.writer(novo_arquivo, dialect='pVirgula')
    escreve.writerows(ver)

novo_arquivo.close()
vot_f.close()
